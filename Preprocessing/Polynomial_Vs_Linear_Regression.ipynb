# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Sample data generation
np.random.seed(0)
X = np.random.rand(100, 1) * 10  # Generate 100 random numbers between 0 and 10
y = X**2 + np.random.randn(100, 1) * 5  # Quadratic relationship with noise

# Linear regression
model_lin = LinearRegression()
model_lin.fit(X, y)
y_pred_lin = model_lin.predict(X)

# Polynomial feature transformation
poly = PolynomialFeatures(degree=2)  # Use polynomial features up to degree 2
X_poly = poly.fit_transform(X)

# Polynomial regression
model_poly = LinearRegression()
model_poly.fit(X_poly, y)
y_pred_poly = model_poly.predict(X_poly)

# Plot results
plt.scatter(X, y, color='blue', label='Original data')
plt.plot(X, y_pred_lin, color='red', label='Linear Regression')
plt.plot(X, y_pred_poly, color='green', label='Polynomial Regression (de-gree=2)')
plt.title('Linear vs Polynomial Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# Evaluate models
mse_lin = mean_squared_error(y, y_pred_lin)
mse_poly = mean_squared_error(y, y_pred_poly)
print("Mean Squared Error (Linear Regression):", mse_lin)
print("Mean Squared Error (Polynomial Regression):", mse_poly)
# Out:
# Mean Squared Error (Linear Regression): 72.14987877031551
# Mean Squared Error (Polynomial Regression): 24.338941808535537
